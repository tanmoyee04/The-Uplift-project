# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmoyee04/The-Uplift-project/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
rs = pd.read_csv('weather.csv')
rs
# Out:
#           EST  Temperature  DewPoint  ...  CloudCover    Events  WindDirDegrees
# 0    1/1/2016           38        23  ...           5       NaN             281
# 1    1/2/2016           36        18  ...           3       NaN             275
# 2    1/3/2016           40        21  ...           1       NaN             277
# 3    1/4/2016           25         9  ...           3       NaN             345
# 4    1/5/2016           20        -3  ...           0       NaN             333
# 5    1/6/2016           33         4  ...           0       NaN             259
# 6    1/7/2016           39        11  ...           3       NaN             293
# 7    1/8/2016           39        29  ...           8       NaN              79
# 8    1/9/2016           44        38  ...           8      Rain              76
# 9   1/10/2016           50        46  ...           7      Rain             109
# 10  1/11/2016           33         8  ...           1       NaN             289
# ...

# %%
rs.head() #default is 5
# Out:
#         EST  Temperature  DewPoint  ...  CloudCover  Events  WindDirDegrees
# 0  1/1/2016           38        23  ...           5     NaN             281
# 1  1/2/2016           36        18  ...           3     NaN             275
# 2  1/3/2016           40        21  ...           1     NaN             277
# 3  1/4/2016           25         9  ...           3     NaN             345
# 4  1/5/2016           20        -3  ...           0     NaN             333
#
# [5 rows x 11 columns]

# %%
rs.head(10)
# Out:
#          EST  Temperature  DewPoint  ...  CloudCover  Events  WindDirDegrees
# 0   1/1/2016           38        23  ...           5     NaN             281
# 1   1/2/2016           36        18  ...           3     NaN             275
# 2   1/3/2016           40        21  ...           1     NaN             277
# 3   1/4/2016           25         9  ...           3     NaN             345
# 4   1/5/2016           20        -3  ...           0     NaN             333
# 5   1/6/2016           33         4  ...           0     NaN             259
# 6   1/7/2016           39        11  ...           3     NaN             293
# 7   1/8/2016           39        29  ...           8     NaN              79
# 8   1/9/2016           44        38  ...           8    Rain              76
# 9  1/10/2016           50        46  ...           7    Rain             109
#
# [10 rows x 11 columns]

# %%
rs.tail() #default is 5
# Out:
#           EST  Temperature  DewPoint  ...  CloudCover  Events  WindDirDegrees
# 26  1/27/2016           41        22  ...           3    Rain             311
# 27  1/28/2016           37        20  ...           1     NaN             234
# 28  1/29/2016           36        21  ...           4     NaN             298
# 29  1/30/2016           34        16  ...           0     NaN             257
# 30  1/31/2016           46        28  ...           0     NaN             241
#
# [5 rows x 11 columns]

# %%
rs.shape #shows no. of rows and columns
# Out:
# (31, 11)

# %%
rs[2:5] #row slicing
# Out:
#         EST  Temperature  DewPoint  ...  CloudCover  Events  WindDirDegrees
# 2  1/3/2016           40        21  ...           1     NaN             277
# 3  1/4/2016           25         9  ...           3     NaN             345
# 4  1/5/2016           20        -3  ...           0     NaN             333
#
# [3 rows x 11 columns]

# %%
rs.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
rs[['EST','Temperature','DewPoint']] #column slicing
# Out:
#           EST  Temperature  DewPoint
# 0    1/1/2016           38        23
# 1    1/2/2016           36        18
# 2    1/3/2016           40        21
# 3    1/4/2016           25         9
# 4    1/5/2016           20        -3
# 5    1/6/2016           33         4
# 6    1/7/2016           39        11
# 7    1/8/2016           39        29
# 8    1/9/2016           44        38
# 9   1/10/2016           50        46
# 10  1/11/2016           33         8
# 11  1/12/2016           35        15
# 12  1/13/2016           26         4
# 13  1/14/2016           30        12
# 14  1/15/2016           43        31
# 15  1/16/2016           47        37
# 16  1/17/2016           36        23
# 17  1/18/2016           25         6
# 18  1/19/2016           22         3
# 19  1/20/2016           32        15
# 20  1/21/2016           31        11
# 21  1/22/2016           26         6
# 22  1/23/2016           26        21
# 23  1/24/2016           28        11
# ...

# %%
rs.loc[2:10,['EST','Temperature','DewPoint']] #both row n column slicing
# Out:
#           EST  Temperature  DewPoint
# 2    1/3/2016           40        21
# 3    1/4/2016           25         9
# 4    1/5/2016           20        -3
# 5    1/6/2016           33         4
# 6    1/7/2016           39        11
# 7    1/8/2016           39        29
# 8    1/9/2016           44        38
# 9   1/10/2016           50        46
# 10  1/11/2016           33         8

# %%
rs.iloc[2:10,0:3]
# Out:
#          EST  Temperature  DewPoint
# 2   1/3/2016           40        21
# 3   1/4/2016           25         9
# 4   1/5/2016           20        -3
# 5   1/6/2016           33         4
# 6   1/7/2016           39        11
# 7   1/8/2016           39        29
# 8   1/9/2016           44        38
# 9  1/10/2016           50        46

# %%
rs.describe() #statistical datas are calculated
# Out:
#        Temperature   DewPoint  ...  CloudCover  WindDirDegrees
# count    31.000000  31.000000  ...   31.000000       31.000000
# mean     34.677419  17.838710  ...    3.129032      247.129032
# std       7.639315  11.378626  ...    2.629853       92.308086
# min      20.000000  -3.000000  ...    0.000000       34.000000
# 25%      29.000000  10.000000  ...    1.000000      238.000000
# 50%      35.000000  18.000000  ...    3.000000      281.000000
# 75%      39.500000  23.000000  ...    4.500000      300.000000
# max      50.000000  46.000000  ...    8.000000      345.000000
#
# [8 rows x 8 columns]

# %%
rs1 = rs.set_index('EST') #changing the index
rs1
# Out:
#            Temperature  DewPoint  ...    Events  WindDirDegrees
# EST                               ...
# 1/1/2016            38        23  ...       NaN             281
# 1/2/2016            36        18  ...       NaN             275
# 1/3/2016            40        21  ...       NaN             277
# 1/4/2016            25         9  ...       NaN             345
# 1/5/2016            20        -3  ...       NaN             333
# 1/6/2016            33         4  ...       NaN             259
# 1/7/2016            39        11  ...       NaN             293
# 1/8/2016            39        29  ...       NaN              79
# 1/9/2016            44        38  ...      Rain              76
# 1/10/2016           50        46  ...      Rain             109
# 1/11/2016           33         8  ...       NaN             289
# 1/12/2016           35        15  ...       NaN             235
# 1/13/2016           26         4  ...       NaN             284
# ...

# %%
rs1.reset_index(inplace=True)
rs1
# Out:
#           EST  Temperature  DewPoint  ...  CloudCover    Events  WindDirDegrees
# 0    1/1/2016           38        23  ...           5       NaN             281
# 1    1/2/2016           36        18  ...           3       NaN             275
# 2    1/3/2016           40        21  ...           1       NaN             277
# 3    1/4/2016           25         9  ...           3       NaN             345
# 4    1/5/2016           20        -3  ...           0       NaN             333
# 5    1/6/2016           33         4  ...           0       NaN             259
# 6    1/7/2016           39        11  ...           3       NaN             293
# 7    1/8/2016           39        29  ...           8       NaN              79
# 8    1/9/2016           44        38  ...           8      Rain              76
# 9   1/10/2016           50        46  ...           7      Rain             109
# 10  1/11/2016           33         8  ...           1       NaN             289
# ...

# %%
type(rs1)
# Out:
# pandas.core.frame.DataFrame

# %%
l1 = [('19/06/2021',154),('04/11/2020',110),('05/03/2021',291),('10/06/2021',184)] #creating dataframe using list
data = pd.DataFrame(l1,columns=['date','WindSpeed'])
data
# Out:
#          date  WindSpeed
# 0  19/06/2021        154
# 1  04/11/2020        110
# 2  05/03/2021        291
# 3  10/06/2021        184

# %%
dic = {
    "Date": ["11/06/2021","07/03/2021","15/03/2021","10/05/2021"], ##creating dataframe using dictionary
    "WindSpeed": [105,290,44,78]
}
data2 = pd.DataFrame(dic)
data2
# Out:
#          Date  WindSpeed
# 0  11/06/2021        105
# 1  07/03/2021        290
# 2  15/03/2021         44
# 3  10/05/2021         78

# %%
data3 = pd.concat([data,data2],ignore_index=True)
data3
# Out:
#          date  WindSpeed        Date
# 0  19/06/2021        154         NaN
# 1  04/11/2020        110         NaN
# 2  05/03/2021        291         NaN
# 3  10/06/2021        184         NaN
# 4         NaN        105  11/06/2021
# 5         NaN        290  07/03/2021
# 6         NaN         44  15/03/2021
# 7         NaN         78  10/05/2021

# %%
rs2=rs1.dropna()
rs2
# Out:
#           EST  Temperature  DewPoint  ...  CloudCover    Events  WindDirDegrees
# 8    1/9/2016           44        38  ...           8      Rain              76
# 15  1/16/2016           47        37  ...           7      Rain             340
# 16  1/17/2016           36        23  ...           6  Fog-Snow             345
# 17  1/18/2016           25         6  ...           2      Snow             293
# 22  1/23/2016           26        21  ...           8  Fog-Snow              42
# 23  1/24/2016           28        11  ...           3      Snow             327
# 26  1/27/2016           41        22  ...           3      Rain             311
#
# [7 rows x 11 columns]

# %%
rs2.to_csv('file.csv')

# %%
#Normalisation & standsardisation

goog = pd.read_csv('GOOG.csv')

# %%
goog
# Out:
#           Date         Open         High  ...        Close    Adj Close   Volume
# 0   2020-05-20  1389.579956  1410.420044  ...  1406.719971  1406.719971  1655400
# 1   2020-05-21  1408.000000  1415.489990  ...  1402.800049  1402.800049  1385000
# 2   2020-05-22  1396.709961  1412.760010  ...  1410.420044  1410.420044  1309400
# 3   2020-05-26  1437.270020  1441.000000  ...  1417.020020  1417.020020  2060600
# 4   2020-05-27  1417.250000  1421.739990  ...  1417.839966  1417.839966  1685800
# ..         ...          ...          ...  ...          ...          ...      ...
# 59  2020-08-13  1510.339966  1537.250000  ...  1518.449951  1518.449951  1455200
# 60  2020-08-14  1515.660034  1521.900024  ...  1507.729980  1507.729980  1354800
# 61  2020-08-17  1514.670044  1525.609985  ...  1517.979980  1517.979980  1378300
# 62  2020-08-18  1526.180054  1562.469971  ...  1558.599976  1558.599976  2027100
# 63  2020-08-19  1553.310059  1573.680054  ...  1547.530029  1547.530029  1660000
#
# ...

# %%
#Normalisation
from sklearn.preprocessing import MinMaxScaler

# %%
goog.set_index('Date',inplace=True)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
data = scaler.fit_transform(goog)

# %%
data
# Out:
# array([[0.13723137, 0.07743386, 0.19414284, 0.22445925, 0.22445925,
#         0.21686603],
#        [0.21773506, 0.10392399, 0.22405527, 0.20566677, 0.20566677,
#         0.13580358],
#        [0.16839263, 0.08966003, 0.21623941, 0.24219775, 0.24219775,
#         0.11313967],
#        [0.34565792, 0.23721208, 0.31417952, 0.27383866, 0.27383866,
#         0.33833978],
#        [0.25816163, 0.13657982, 0.21363451, 0.27776955, 0.27776955,
#         0.22597955],
#        [0.1690483 , 0.23637592, 0.2363583 , 0.27244818, 0.27244818,
#         0.22789819],
#        [0.25680654, 0.19316562, 0.32006542, 0.3308885 , 0.3308885 ,
#         0.27163714],
#        [0.263144  , 0.22132808, 0.34250004, 0.3447909 , 0.3447909 ,
#         0.08546932],
#        [0.31628869, 0.22994935, 0.34650427, 0.38026732, 0.38026732,
#         0.10375633],
#        [0.3501596 , 0.26622092, 0.39931954, 0.36665225, 0.36665225,
#         0.09719099],
#        [0.31563302, 0.22655302, 0.27847718, 0.2506354 , 0.2506354 ,
# ...

# %%
#Standardisation
scaler = MinMaxScaler(feature_range=(0,1))
data = scaler.fit_transform(goog)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler().fit(goog)
data = scaler.transform(goog)
data
# Out:
# array([[-1.6016169 , -1.55498185, -1.37243425, -1.33916938, -1.33916938,
#         -0.04850997],
#        [-1.22982093, -1.45239246, -1.24447994, -1.41929474, -1.41929474,
#         -0.5741136 ],
#        [-1.45770263, -1.50763308, -1.27791332, -1.26353786, -1.26353786,
#         -0.72106491],
#        [-0.63902562, -0.93620225, -0.85896182, -1.12863072, -1.12863072,
#          0.73911796],
#        [-1.04311601, -1.32592489, -1.28905611, -1.11187058, -1.11187058,
#          0.01058156],
#        [-1.4546745 , -0.93944051, -1.19185214, -1.1345593 , -1.1345593 ,
#          0.02302189],
#        [-1.04937434, -1.10678279, -0.83378412, -0.8853877 , -0.8853877 ,
#          0.30662237],
#        [-1.02010559, -0.99771686, -0.73781713, -0.82611211, -0.82611211,
#         -0.90047769],
#        [-0.77466363, -0.96432894, -0.72068854, -0.67485153, -0.67485153,
#         -0.78190586],
#        [-0.61823519, -0.82385855, -0.49476439, -0.732902  , -0.732902  ,
#         -0.82447509],
# ...
